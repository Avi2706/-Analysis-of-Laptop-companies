# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("laptop_price - dataset.csv")

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
df.describe(include = "all")
# Out:
#        Company Product  TypeName       Inches   ScreenResolution CPU_Company  \
# count     1275    1275      1275  1275.000000               1275        1275
# unique      19     618         6          NaN                 40           3
# top       Dell  XPS 13  Notebook          NaN  Full HD 1920x1080       Intel
# freq       291      30       707          NaN                505        1214
# mean       NaN     NaN       NaN    15.022902                NaN         NaN
# std        NaN     NaN       NaN     1.429470                NaN         NaN
# min        NaN     NaN       NaN    10.100000                NaN         NaN
# 25%        NaN     NaN       NaN    14.000000                NaN         NaN
# 50%        NaN     NaN       NaN    15.600000                NaN         NaN
# 75%        NaN     NaN       NaN    15.600000                NaN         NaN
# max        NaN     NaN       NaN    18.400000                NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1275 non-null   object
#  1   Product              1275 non-null   object
#  2   TypeName             1275 non-null   object
#  3   Inches               1275 non-null   float64
#  4   ScreenResolution     1275 non-null   object
#  5   CPU_Company          1275 non-null   object
#  6   CPU_Type             1275 non-null   object
#  7   CPU_Frequency (GHz)  1275 non-null   float64
#  8   RAM (GB)             1275 non-null   int64
#  9   Memory               1275 non-null   object
#  10  GPU_Company          1275 non-null   object
#  11  GPU_Type             1275 non-null   object
#  12  OpSys                1275 non-null   object
#  13  Weight (kg)          1275 non-null   float64
#  14  Price (Euro)         1275 non-null   float64
# ...

# %%
df.size
# Out:
# 19125

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution',
#        'CPU_Company', 'CPU_Type', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Memory',
#        'GPU_Company', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
df.sample(4)
# Out:
#     Company            Product  TypeName  Inches             ScreenResolution  \
# 203  Lenovo  Legion Y720-15IKB    Gaming    15.6  IPS Panel Full HD 1920x1080
# 109  Lenovo      Thinkpad T470  Notebook    14.0  IPS Panel Full HD 1920x1080
# 202    Acer     Aspire E5-576G  Notebook    15.6            Full HD 1920x1080
# 167    Dell      Inspiron 5577    Gaming    15.6            Full HD 1920x1080
#
#     CPU_Company        CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 203       Intel  Core i7 7700HQ                  2.8        16
# 109       Intel   Core i7 7500U                  2.7         8
# 202       Intel   Core i7 7500U                  2.7         8
# 167       Intel  Core i7 7700HQ                  2.8         8
#
#                    Memory GPU_Company          GPU_Type       OpSys  \
# 203  512GB SSD +  1TB HDD      Nvidia  GeForce GTX 1060  Windows 10
# 109             256GB SSD       Intel   HD Graphics 620  Windows 10
# ...

# %%
k = df.groupby(['Company'],as_index=False)['Price (Euro)'].sum()

k
# Out:
#       Company  Price (Euro)
# 0        Acer      63979.91
# 1       Apple      32848.17
# 2        Asus     170822.12
# 3       Chuwi        942.89
# 4        Dell     348974.51
# 5     Fujitsu       2187.00
# 6      Google       5033.00
# 7          HP     289524.33
# 8      Huawei       2848.00
# 9          LG       6297.00
# 10     Lenovo     316126.18
# 11        MSI      93361.04
# 12   Mediacom       2065.00
# 13  Microsoft       9673.85
# 14      Razer      23423.00
# 15    Samsung      12721.00
# 16    Toshiba      60855.00
# 17       Vero        869.70
# 18     Xiaomi       4533.85

# %%
g = df.groupby(["TypeName"])["Price (Euro)"].sum()
g
# Out:
# TypeName
# 2 in 1 Convertible    150896.60
# Gaming                354933.03
# Netbook                15487.80
# Notebook              557642.56
# Ultrabook             301995.15
# Workstation            66130.41
# Name: Price (Euro), dtype: float64

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
sns.catplot(
    data = df,
    y = df['CPU_Type'],
    x = df['Price (Euro)'],
    kind = 'bar',
    height = 15


    
)
plt.show()

# %%
# here we see costest proccessor or cpu

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
cm = df.corr(numeric_only = True)
cm
# Out:
#                        Inches  CPU_Frequency (GHz)  RAM (GB)  Weight (kg)  \
# Inches               1.000000             0.305037  0.241078     0.826638
# CPU_Frequency (GHz)  0.305037             1.000000  0.366254     0.318649
# RAM (GB)             0.241078             0.366254  1.000000     0.389370
# Weight (kg)          0.826638             0.318649  0.389370     1.000000
# Price (Euro)         0.066608             0.428847  0.740287     0.211883
#
#                      Price (Euro)
# Inches                   0.066608
# CPU_Frequency (GHz)      0.428847
# RAM (GB)                 0.740287
# Weight (kg)              0.211883
# Price (Euro)             1.000000

# %%
sns.heatmap( cm,annot=  True
    
)
plt.show()

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
sns.catplot(
    kind = 'bar',
    x = df['Company'],
    y = df['Price (Euro)'],
    aspect = 3,
    palette = 'viridis'
)
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_9856\2937018094.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(

# %%
# through this graph we can clearlly see which comapny make high price laptop

# %%
f = df.groupby(['Company'],as_index = True )['Price (Euro)'].sum()
f
# Out:
# Company
# Acer          63979.91
# Apple         32848.17
# Asus         170822.12
# Chuwi           942.89
# Dell         348974.51
# Fujitsu        2187.00
# Google         5033.00
# HP           289524.33
# Huawei         2848.00
# LG             6297.00
# Lenovo       316126.18
# MSI           93361.04
# Mediacom       2065.00
# Microsoft      9673.85
# Razer         23423.00
# Samsung       12721.00
# Toshiba       60855.00
# Vero            869.70
# Xiaomi         4533.85
# Name: Price (Euro), dtype: float64

# %%
sort_co = df.groupby(['Company'], as_index=False)['Price (Euro)'].sum().sort_values(by='Price (Euro)', ascending=False)
sort_co.head(5)
# Out:
#    Company  Price (Euro)
# 4     Dell     348974.51
# 10  Lenovo     316126.18
# 7       HP     289524.33
# 2     Asus     170822.12
# 11     MSI      93361.04

# %%
F = df.groupby(['Company'],as_index = False)['Price (Euro)'].sum().sort_values(by='Price (Euro)',ascending = False)
f.head(5)
# Out:
# Company
# Acer      63979.91
# Apple     32848.17
# Asus     170822.12
# Chuwi       942.89
# Dell     348974.51
# Name: Price (Euro), dtype: float64

# %%
df = pd.read_csv("laptop_price - dataset.csv")

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   CPU_Company       CPU_Type  CPU_Frequency (GHz)  RAM (GB)  \
# 0       Intel        Core i5                  2.3         8
# 1       Intel        Core i5                  1.8         8
# 2       Intel  Core i5 7200U                  2.5         8
# 3       Intel        Core i7                  2.7        16
# 4       Intel        Core i5                  3.1         8
#
#                 Memory GPU_Company                GPU_Type  OpSys  \
# ...

# %%
sns.countplot(x = "Company",data =  df)
plt.xticks(rotation =90)
plt.show()

# %%
# here we can see which company is leading manufacted of computer

# %%
plt.figure(figsize = (5,5))
sns.histplot(x = "TypeName" , data = df)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Ultrabook'),
#   Text(1, 0, 'Notebook'),
#   Text(2, 0, 'Netbook'),
#   Text(3, 0, 'Gaming'),
#   Text(4, 0, '2 in 1 Convertible'),
#   Text(5, 0, 'Workstation')])

# %%
## here we can see the  which type of the laptop most use by useres

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution',
#        'CPU_Company', 'CPU_Type', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Memory',
#        'GPU_Company', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
plt.pie(df)

# %%
gb = df.groupby("TypeName").agg({"TypeName":"count"})
gb
a = plt.pie(gb["TypeName"],autopct = "%1.2f%%")
 

plt.show()

# %%
gb= df.groupby("TypeName").agg({"TypeName" : "count"})
gb
# Out:
#                     TypeName
# TypeName
# 2 in 1 Convertible       117
# Gaming                   205
# Netbook                   23
# Notebook                 707
# Ultrabook                194
# Workstation               29
